# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=r'C:\Users\IksuraW\Downloads\New folder\ClothTagNetV2\test_img\PXL_20260127_051830384.MP.jpg'

# %%
image = cv2.imread(img)
# Convert BGR → RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis("off")
plt.show()

# %%
import cv2
import numpy as np

cap=cv2.VideoCapture(0)

while True:
    _,frame=cap.read()
