# %%
import easyocr
import time
import re

# %%
def extract_text(image_path):
    """
    Extract all text from an image using EasyOCR (English only).
    Returns a list of text strings found in the image.
    """
    # Initialize reader for English
    reader = easyocr.Reader(['en'], gpu=False)
    
    # Extract text (detail=0 returns only text strings)
    results = reader.readtext(image_path, detail=0)
    
    return results

# %% [markdown]
# CPU RUN

# %%
image_file = r"C:\Users\IksuraW\Downloads\New folder\ClothTagNetV2\Screenshot 2025-10-13 155841.png"  # Replace with your image path
    
    # Get text as list
text_list = extract_text(image_file)
print("Extracted text (list):")
for text in text_list:
    print(f"- {text}")
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# c:\Users\IksuraW\Downloads\New folder\ClothTagNetV2\env\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Extracted text (list):
# - preset
# - meaning
# - cron
# - None
# - Don"t schedule, use for exclusively "externally triggered" DAGs
# - @once
# - Schedule once and only once
# - @continuous
# - Run as soon as the previous run finishes
# - @hourly
# - Run once an hour at Ihe end of the hour
# - @daily
# - Run once
# - day at midnight (24.00)
# - @veckly
# - Run once
# - week at midnight (24.00) on Sunday
# - @monthly
# - Run once
# - month at midnight (24.00) of the first day of the month
# - @quarterly
# - Run once
# - quarter at midnight (24.00) on the-
# - day
# - #/3
# - @yearly
# - Run once
# - year at midnight (24.00) of January
# - 1 1 *
# - Fucst C

# %% [markdown]
#  GPU RUN

# %%
start_time = time.time()
use_cuda = True
text_list = extract_text(image_file) #, use_gpu=use_cuda use this to enable gpu
end_time = time.time()
elapsed_time = end_time - start_time
paragraph = " ".join(text_list)
paragraph = paragraph.lower()  # Convert to lowercase for uniformity
print("Extracted Text:")
print(paragraph)
print(f"\nTime consumed: {elapsed_time:.2f} seconds")
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# c:\Users\IksuraW\Downloads\New folder\ClothTagNetV2\env\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Extracted Text:
# preset meaning cron none don"t schedule, use for exclusively "externally triggered" dags @once schedule once and only once @continuous run as soon as the previous run finishes @hourly run once an hour at ihe end of the hour @daily run once day at midnight (24.00) @veckly run once week at midnight (24.00) on sunday @monthly run once month at midnight (24.00) of the first day of the month @quarterly run once quarter at midnight (24.00) on the- day #/3 @yearly run once year at midnight (24.00) of january 1 1 * fucst c
#
# Time consumed: 6.71 seconds
